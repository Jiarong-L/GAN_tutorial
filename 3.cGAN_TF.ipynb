# %%
import tensorflow as tf
import keras
from keras import layers
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Load Dataset

# %%
(train_imgs,train_labels),(test_imgs,test_labels) = tf.keras.datasets.mnist.load_data(path="L:/Datasets/mnist.npz")

BufferSize = train_imgs.shape[0]
BatchSize = 128

train_imgs = train_imgs/127.5-1
train_imgs = tf.expand_dims(train_imgs,-1)
trainloader = tf.data.Dataset.from_tensor_slices((train_imgs,train_labels)).shuffle(BufferSize).batch(BatchSize)

# %%
train_imgs.shape
# Out:
# TensorShape([60000, 28, 28, 1])

# %%
## View Img
def showBatchImg(images,labels,maxNum=5):
    fig, axes = plt.subplots(1, maxNum)
    for i in range(maxNum):
        axes[i].imshow(images[i].numpy().squeeze())
        axes[i].set_title(labels[i].item())
        axes[i].axis('off')
    plt.show()

showBatchImg(train_imgs, train_labels, 10)

# %% [markdown]
# ## cGAN Model
#
# ```
# concatenate[noise,label] ==> Generator ==>  Fake_Img |
#                                                      |==> concatenate[_Img,label] ==> Discriminator ==> 0/1
#                                             Real_Img |
# ```
#
# 启发：pix2pix GAN 图像风格迁徙（e.g.给灰图上色，给轮廓图加细节）
# ```
# Raw_Img ==> Generator ==> Fake_Colored_Img |
#                                            | ==> Discriminator ==> 0/1
#                           Real_Colored_Img |
#
#
#          Generator Loss = Binary(1,desc_Fake) + L1_Loss(Real,Fake)    保证二者之间的相似度
#      Discriminator Loss = Binary(1,Real_Fake) + Binary(0,desc_Fake)
#
# Generator 使用Unet保证留存轮廓
# Raw_Img、Real_Colored_Img 需要严格的成对数据
# ```
#
#
# 启发：Cycle GAN 将X空间的图像风格迁徙至Y空间的图像中
# ```
#                                ——————————>GeneratorB——————>Fake_X_Img
#                               |
# X_Img ==> GeneratorA ==> Fake_Y_Img |
#                                     | ==> Discriminator ==> 0/1
#                               Y_Img |
#
#          Generator Loss = Binary(1,desc_Fake) + L2_Loss(Fake_X_Img,X_Img)  为了防止Generator生成无关的图片
#      Discriminator Loss = Binary(1,Real_Fake) + Binary(0,desc_Fake)
#
# 不需要严格的成对数据，只需要标记图片属于X空间还是Y空间
# ```

# %%
noise_len = 50
label_num = 10

def Generator(): 
    seed = layers.Input(shape=(noise_len,))
    label = layers.Input(shape=(()))
    
    Embd = layers.Embedding(label_num,noise_len)(label)
    # Embd = layers.Reshape((noise_len,))(Embd)
    x = layers.concatenate([seed,Embd])                           ## B*100
    x = keras.Sequential(
    [
        # layers.LayerNormalization(),
        layers.Dense(3*3*128,use_bias = False),                      ##  B*? ==> B*-
        layers.Reshape((3,3,128)),                                   ##      ==> B*3*3*128
        layers.BatchNormalization(), 
        layers.ReLU(),
        layers.Conv2DTranspose(64, 3, 2, use_bias=False),            ##      ==> B*7*7*64      ##  filters, kernel_size, strides
        layers.BatchNormalization(),                                                            ## = *strides + max(0,kernel_size-strides)
        layers.ReLU(),
        layers.Conv2DTranspose(32, 3, 2, padding="same", use_bias=False), ## ==> B*14*14*32     
        layers.BatchNormalization(), 
        layers.ReLU(),
        layers.Conv2DTranspose(1, 3, 2, padding="same", use_bias=False),  ## ==> B*28*28*1
        layers.Activation('tanh')
    ])(x)
    GModel = tf.keras.Model(inputs=[seed,label],outputs=x)
    return GModel

def Discriminator():
    label = layers.Input(shape=(()))
    img = layers.Input(shape=(28,28,1))

    Embd = layers.Embedding(label_num,28*28)(label)
    Embd = layers.Reshape((28,28,1))(Embd)
    x = layers.concatenate([img,Embd])                        ## B*28*28*2
    x = keras.Sequential(
    [
        # layers.LayerNormalization(),
        layers.Conv2D(32, (3, 3),strides=(2, 2), padding="same", use_bias=False),    ##  ==> B*14*14*32
        layers.BatchNormalization(), 
        layers.LeakyReLU(),
        layers.Dropout(0.5), 
        layers.Conv2D(64, (3, 3),strides=(2, 2), padding="same", use_bias=False),    ##  ==> B*7*7*64
        layers.BatchNormalization(), 
        layers.LeakyReLU(),
        layers.Dropout(0.5),  
        layers.Conv2D(128, (3, 3),strides=(2, 2), padding="same", use_bias=False),  
        layers.BatchNormalization(), 
        layers.LeakyReLU(),
        layers.Dropout(0.5),  
        layers.Flatten(),                                                            ##  ==> B*3136
        layers.Dense(1)                                                              ## logits: 未被 Activation 处理
    ])(x)
    DModel = tf.keras.Model(inputs=[img,label],outputs=x)
    return DModel

# ## Call Model ##############################
# img = tf.ones((2, 28,28,1))
# seed = tf.ones((2, noise_len))
# label = tf.ones((2, 1))

# # DModel = Discriminator()
# # DModel((img,label)).shape

# # GModel = Generator()
# # GModel((seed,label)).shape

# %%
DModel = Discriminator()
GModel = Generator()

bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
optG = tf.keras.optimizers.Adam(learning_rate=1e-4, beta_1=0.5)
optD = tf.keras.optimizers.Adam(learning_rate=1e-4)

def lossDfn(predR,predF):
    lossR = bce(tf.ones_like(predR),predR)
    lossF = bce(tf.zeros_like(predF),predF)
    return lossR+lossF

def lossGfn(predF):
    return bce(tf.ones_like(predF),predF)

@tf.function
def trainStep(Images,Labels):
    Seeds = tf.random.normal([Labels.shape[0],noise_len])
    with tf.GradientTape() as tapeG, tf.GradientTape() as tapeD:
        FakeImgs = GModel((Seeds,Labels),training=True)
        predF = DModel((FakeImgs,Labels),training=True)
        predR = DModel((Images,Labels),training=True)
        lossG = lossGfn(predF)
        lossD = lossDfn(predR,predF)
    gradG = tapeG.gradient(lossG,GModel.trainable_variables) 
    gradD = tapeD.gradient(lossD,DModel.trainable_variables)
    optG.apply_gradients(zip(gradG,GModel.trainable_variables))
    optD.apply_gradients(zip(gradD,DModel.trainable_variables))
    return lossG,lossD


def testStep(test_num = 10):
    testlabel = np.random.randint(10, size=test_num)
    testseed =tf.random.normal([test_num,noise_len])
    FakeImgs = GModel((testseed,tf.convert_to_tensor(testlabel)),training=False)
    showBatchImg(FakeImgs, testlabel)


for epoch in range(50):
    counter = 0
    for _ , (Images,Labels) in enumerate(trainloader):
        lossG,lossD = trainStep(Images,Labels)
        counter += 1
        if counter%100 == 5:
            print(f'Epoch {epoch+1}----Generator Loss:: {lossG:>7f}----Discriminator Loss:: {lossD:>7f}')
            DModel.save_weights('tmp/D.weights.h5')
        if counter%100 == 55:
            DModel.load_weights('tmp/D.weights.h5')
    testStep(test_num = 10)
# Out:
# Epoch 1----Generator Loss:: 0.951558----Discriminator Loss:: 1.426970
# Epoch 1----Generator Loss:: 1.555287----Discriminator Loss:: 0.950883
# Epoch 1----Generator Loss:: 1.555781----Discriminator Loss:: 0.810460
# Epoch 1----Generator Loss:: 1.477323----Discriminator Loss:: 1.044825
# Epoch 1----Generator Loss:: 1.459539----Discriminator Loss:: 0.879931
# Epoch 2----Generator Loss:: 1.608757----Discriminator Loss:: 1.283789
# Epoch 2----Generator Loss:: 1.731134----Discriminator Loss:: 0.731992
# Epoch 2----Generator Loss:: 1.545802----Discriminator Loss:: 1.028682
# Epoch 2----Generator Loss:: 1.639160----Discriminator Loss:: 0.867927
# Epoch 2----Generator Loss:: 1.871561----Discriminator Loss:: 0.808851
# Epoch 3----Generator Loss:: 1.632553----Discriminator Loss:: 1.341126
# Epoch 3----Generator Loss:: 1.884502----Discriminator Loss:: 0.627922
# Epoch 3----Generator Loss:: 1.873323----Discriminator Loss:: 0.548464
# Epoch 3----Generator Loss:: 1.659948----Discriminator Loss:: 0.921555
# Epoch 3----Generator Loss:: 2.231537----Discriminator Loss:: 0.486127
# Epoch 4----Generator Loss:: 2.042101----Discriminator Loss:: 1.152024
# Epoch 4----Generator Loss:: 2.181167----Discriminator Loss:: 0.564329
# Epoch 4----Generator Loss:: 1.586599----Discriminator Loss:: 0.721035
# Epoch 4----Generator Loss:: 1.552626----Discriminator Loss:: 0.691873
# Epoch 4----Generator Loss:: 1.713049----Discriminator Loss:: 0.664355
# Epoch 5----Generator Loss:: 2.312530----Discriminator Loss:: 1.171055
# Epoch 5----Generator Loss:: 1.544669----Discriminator Loss:: 0.767091
# Epoch 5----Generator Loss:: 1.813111----Discriminator Loss:: 0.508698
# Epoch 5----Generator Loss:: 1.548398----Discriminator Loss:: 0.846772
# Epoch 5----Generator Loss:: 1.615602----Discriminator Loss:: 0.778503
# Epoch 6----Generator Loss:: 2.329856----Discriminator Loss:: 1.072913
# Epoch 6----Generator Loss:: 1.618127----Discriminator Loss:: 0.692164
# Epoch 6----Generator Loss:: 1.434440----Discriminator Loss:: 0.772113
# Epoch 6----Generator Loss:: 1.665390----Discriminator Loss:: 0.600046
# Epoch 6----Generator Loss:: 1.147794----Discriminator Loss:: 1.175566
# Epoch 7----Generator Loss:: 1.794112----Discriminator Loss:: 1.468107
# Epoch 7----Generator Loss:: 1.639558----Discriminator Loss:: 0.691587
# Epoch 7----Generator Loss:: 1.023132----Discriminator Loss:: 1.049162
# Epoch 7----Generator Loss:: 1.543720----Discriminator Loss:: 0.786389
# Epoch 7----Generator Loss:: 1.354373----Discriminator Loss:: 0.952375
# Epoch 8----Generator Loss:: 1.484728----Discriminator Loss:: 1.250453
# Epoch 8----Generator Loss:: 1.406464----Discriminator Loss:: 0.839121
# Epoch 8----Generator Loss:: 1.459248----Discriminator Loss:: 0.764085
# Epoch 8----Generator Loss:: 1.243238----Discriminator Loss:: 0.890315
# Epoch 8----Generator Loss:: 1.273835----Discriminator Loss:: 0.871276
# Epoch 9----Generator Loss:: 1.455560----Discriminator Loss:: 1.199012
# Epoch 9----Generator Loss:: 1.405115----Discriminator Loss:: 0.912719
# Epoch 9----Generator Loss:: 1.518356----Discriminator Loss:: 0.789311
# Epoch 9----Generator Loss:: 1.059496----Discriminator Loss:: 1.112205
# Epoch 9----Generator Loss:: 1.110493----Discriminator Loss:: 1.050794
# Epoch 10----Generator Loss:: 1.676845----Discriminator Loss:: 1.339419
# Epoch 10----Generator Loss:: 1.248679----Discriminator Loss:: 1.079171
# Epoch 10----Generator Loss:: 1.086278----Discriminator Loss:: 1.057856
# Epoch 10----Generator Loss:: 1.093422----Discriminator Loss:: 1.034615
# Epoch 10----Generator Loss:: 1.290069----Discriminator Loss:: 0.918670
# Epoch 11----Generator Loss:: 1.226016----Discriminator Loss:: 1.460499
# Epoch 11----Generator Loss:: 1.309989----Discriminator Loss:: 0.870001
# Epoch 11----Generator Loss:: 1.194491----Discriminator Loss:: 0.934088
# Epoch 11----Generator Loss:: 1.293824----Discriminator Loss:: 0.890987
# Epoch 11----Generator Loss:: 1.124730----Discriminator Loss:: 1.122489
# Epoch 12----Generator Loss:: 1.108847----Discriminator Loss:: 1.315959
# Epoch 12----Generator Loss:: 0.958241----Discriminator Loss:: 1.310374
# Epoch 12----Generator Loss:: 1.035271----Discriminator Loss:: 1.057445
# Epoch 12----Generator Loss:: 1.144602----Discriminator Loss:: 1.036870
# Epoch 12----Generator Loss:: 1.109721----Discriminator Loss:: 1.063355
# Epoch 13----Generator Loss:: 0.956783----Discriminator Loss:: 1.327893
# Epoch 13----Generator Loss:: 0.979573----Discriminator Loss:: 1.133310
# Epoch 13----Generator Loss:: 1.091947----Discriminator Loss:: 1.122782
# Epoch 13----Generator Loss:: 1.096205----Discriminator Loss:: 1.030039
# Epoch 13----Generator Loss:: 1.080217----Discriminator Loss:: 1.097600
# Epoch 14----Generator Loss:: 1.175363----Discriminator Loss:: 1.203919
# Epoch 14----Generator Loss:: 1.039361----Discriminator Loss:: 1.177417
# Epoch 14----Generator Loss:: 0.894109----Discriminator Loss:: 1.288974
# Epoch 14----Generator Loss:: 1.023503----Discriminator Loss:: 1.035334
# Epoch 14----Generator Loss:: 1.111894----Discriminator Loss:: 1.051035
# Epoch 15----Generator Loss:: 0.999307----Discriminator Loss:: 1.279862
# Epoch 15----Generator Loss:: 0.965751----Discriminator Loss:: 1.225922
# Epoch 15----Generator Loss:: 1.079560----Discriminator Loss:: 1.089215
# Epoch 15----Generator Loss:: 0.992389----Discriminator Loss:: 1.232992
# Epoch 15----Generator Loss:: 1.067280----Discriminator Loss:: 1.135424
# Epoch 16----Generator Loss:: 0.987440----Discriminator Loss:: 1.269880
# Epoch 16----Generator Loss:: 0.989109----Discriminator Loss:: 1.143872
# Epoch 16----Generator Loss:: 0.878407----Discriminator Loss:: 1.360560
# Epoch 16----Generator Loss:: 0.950976----Discriminator Loss:: 1.264117
# Epoch 16----Generator Loss:: 0.810026----Discriminator Loss:: 1.392176
# Epoch 17----Generator Loss:: 0.820644----Discriminator Loss:: 1.357589
# Epoch 17----Generator Loss:: 0.778704----Discriminator Loss:: 1.448604
# Epoch 17----Generator Loss:: 0.837767----Discriminator Loss:: 1.338645
# Epoch 17----Generator Loss:: 0.776746----Discriminator Loss:: 1.380024
# Epoch 17----Generator Loss:: 0.849794----Discriminator Loss:: 1.372106
# Epoch 18----Generator Loss:: 0.827945----Discriminator Loss:: 1.510031
# Epoch 18----Generator Loss:: 0.700151----Discriminator Loss:: 1.455221
# Epoch 18----Generator Loss:: 0.720663----Discriminator Loss:: 1.404070
# Epoch 18----Generator Loss:: 0.819314----Discriminator Loss:: 1.326295
# Epoch 18----Generator Loss:: 0.900656----Discriminator Loss:: 1.266691
# Epoch 19----Generator Loss:: 0.763712----Discriminator Loss:: 1.538852
# Epoch 19----Generator Loss:: 0.748430----Discriminator Loss:: 1.392745
# Epoch 19----Generator Loss:: 0.803951----Discriminator Loss:: 1.299403
# Epoch 19----Generator Loss:: 0.782384----Discriminator Loss:: 1.365195
# Epoch 19----Generator Loss:: 0.771781----Discriminator Loss:: 1.348917
# Epoch 20----Generator Loss:: 0.815711----Discriminator Loss:: 1.433098
# Epoch 20----Generator Loss:: 0.735041----Discriminator Loss:: 1.420810
# Epoch 20----Generator Loss:: 0.696775----Discriminator Loss:: 1.431683
# Epoch 20----Generator Loss:: 0.808454----Discriminator Loss:: 1.298306
# Epoch 20----Generator Loss:: 0.793360----Discriminator Loss:: 1.360534
# Epoch 21----Generator Loss:: 0.725012----Discriminator Loss:: 1.515691
# Epoch 21----Generator Loss:: 0.737142----Discriminator Loss:: 1.403701
# Epoch 21----Generator Loss:: 0.733754----Discriminator Loss:: 1.394981
# Epoch 21----Generator Loss:: 0.767862----Discriminator Loss:: 1.315892
# Epoch 21----Generator Loss:: 0.705168----Discriminator Loss:: 1.376775
# Epoch 22----Generator Loss:: 0.762028----Discriminator Loss:: 1.396909
# Epoch 22----Generator Loss:: 0.729537----Discriminator Loss:: 1.398709
# Epoch 22----Generator Loss:: 0.728766----Discriminator Loss:: 1.333247
# Epoch 22----Generator Loss:: 0.744038----Discriminator Loss:: 1.333474
# Epoch 22----Generator Loss:: 0.783806----Discriminator Loss:: 1.283122
# Epoch 23----Generator Loss:: 0.807659----Discriminator Loss:: 1.468810
# Epoch 23----Generator Loss:: 0.751008----Discriminator Loss:: 1.342762
# Epoch 23----Generator Loss:: 0.746189----Discriminator Loss:: 1.431466
# Epoch 23----Generator Loss:: 0.764884----Discriminator Loss:: 1.339272
# Epoch 23----Generator Loss:: 0.748429----Discriminator Loss:: 1.383087
# Epoch 24----Generator Loss:: 0.810597----Discriminator Loss:: 1.505308
# Epoch 24----Generator Loss:: 0.776177----Discriminator Loss:: 1.337110
# Epoch 24----Generator Loss:: 0.744559----Discriminator Loss:: 1.385161
# Epoch 24----Generator Loss:: 0.760899----Discriminator Loss:: 1.357455
# Epoch 24----Generator Loss:: 0.751754----Discriminator Loss:: 1.332465
# Epoch 25----Generator Loss:: 0.786615----Discriminator Loss:: 1.426025
# Epoch 25----Generator Loss:: 0.790955----Discriminator Loss:: 1.288564
# Epoch 25----Generator Loss:: 0.745212----Discriminator Loss:: 1.346657
# Epoch 25----Generator Loss:: 0.797068----Discriminator Loss:: 1.302865
# Epoch 25----Generator Loss:: 0.812455----Discriminator Loss:: 1.257387
# Epoch 26----Generator Loss:: 0.782424----Discriminator Loss:: 1.401304
# Epoch 26----Generator Loss:: 0.700527----Discriminator Loss:: 1.434035
# Epoch 26----Generator Loss:: 0.730680----Discriminator Loss:: 1.346196
# Epoch 26----Generator Loss:: 0.787824----Discriminator Loss:: 1.319582
# Epoch 26----Generator Loss:: 0.762738----Discriminator Loss:: 1.259822
# Epoch 27----Generator Loss:: 0.846320----Discriminator Loss:: 1.375656
# Epoch 27----Generator Loss:: 0.739412----Discriminator Loss:: 1.335320
# Epoch 27----Generator Loss:: 0.797586----Discriminator Loss:: 1.303933
# Epoch 27----Generator Loss:: 0.825384----Discriminator Loss:: 1.307243
# Epoch 27----Generator Loss:: 0.763563----Discriminator Loss:: 1.358420
# Epoch 28----Generator Loss:: 0.803188----Discriminator Loss:: 1.358959
# Epoch 28----Generator Loss:: 0.753723----Discriminator Loss:: 1.373178
# Epoch 28----Generator Loss:: 0.786351----Discriminator Loss:: 1.303272
# Epoch 28----Generator Loss:: 0.813388----Discriminator Loss:: 1.297310
# Epoch 28----Generator Loss:: 0.789853----Discriminator Loss:: 1.311303
# Epoch 29----Generator Loss:: 0.746929----Discriminator Loss:: 1.416905
# Epoch 29----Generator Loss:: 0.797790----Discriminator Loss:: 1.345638
# Epoch 29----Generator Loss:: 0.767950----Discriminator Loss:: 1.327713
# Epoch 29----Generator Loss:: 0.794141----Discriminator Loss:: 1.349612
# Epoch 29----Generator Loss:: 0.775354----Discriminator Loss:: 1.275295
# Epoch 30----Generator Loss:: 0.799069----Discriminator Loss:: 1.377588
# Epoch 30----Generator Loss:: 0.792617----Discriminator Loss:: 1.347861
# Epoch 30----Generator Loss:: 0.774281----Discriminator Loss:: 1.341923
# Epoch 30----Generator Loss:: 0.778380----Discriminator Loss:: 1.349158
# Epoch 30----Generator Loss:: 0.752145----Discriminator Loss:: 1.329291
# Epoch 31----Generator Loss:: 0.733690----Discriminator Loss:: 1.425468
# Epoch 31----Generator Loss:: 0.755181----Discriminator Loss:: 1.345387
# Epoch 31----Generator Loss:: 0.752106----Discriminator Loss:: 1.334052
# Epoch 31----Generator Loss:: 0.769392----Discriminator Loss:: 1.341952
# Epoch 31----Generator Loss:: 0.767836----Discriminator Loss:: 1.320986
# Epoch 32----Generator Loss:: 0.712595----Discriminator Loss:: 1.436177
# Epoch 32----Generator Loss:: 0.698696----Discriminator Loss:: 1.450151
# Epoch 32----Generator Loss:: 0.718245----Discriminator Loss:: 1.345402
# Epoch 32----Generator Loss:: 0.793487----Discriminator Loss:: 1.265808
# Epoch 32----Generator Loss:: 0.786900----Discriminator Loss:: 1.350895
# Epoch 33----Generator Loss:: 0.708692----Discriminator Loss:: 1.422546
# Epoch 33----Generator Loss:: 0.749864----Discriminator Loss:: 1.347096
# Epoch 33----Generator Loss:: 0.745541----Discriminator Loss:: 1.330444
# Epoch 33----Generator Loss:: 0.782842----Discriminator Loss:: 1.286277
# Epoch 33----Generator Loss:: 0.816727----Discriminator Loss:: 1.265428
# Epoch 34----Generator Loss:: 0.762646----Discriminator Loss:: 1.417810
# Epoch 34----Generator Loss:: 0.700354----Discriminator Loss:: 1.390887
# Epoch 34----Generator Loss:: 0.861822----Discriminator Loss:: 1.221524
# Epoch 34----Generator Loss:: 0.756955----Discriminator Loss:: 1.354386
# Epoch 34----Generator Loss:: 0.807329----Discriminator Loss:: 1.261393
# Epoch 35----Generator Loss:: 0.803027----Discriminator Loss:: 1.321464
# Epoch 35----Generator Loss:: 0.777304----Discriminator Loss:: 1.383907
# Epoch 35----Generator Loss:: 0.764139----Discriminator Loss:: 1.313827
# Epoch 35----Generator Loss:: 0.738140----Discriminator Loss:: 1.368363
# Epoch 35----Generator Loss:: 0.755909----Discriminator Loss:: 1.351964
# Epoch 36----Generator Loss:: 0.748687----Discriminator Loss:: 1.382487
# Epoch 36----Generator Loss:: 0.739520----Discriminator Loss:: 1.356963
# Epoch 36----Generator Loss:: 0.813758----Discriminator Loss:: 1.293378
# Epoch 36----Generator Loss:: 0.752927----Discriminator Loss:: 1.357277
# Epoch 36----Generator Loss:: 0.770504----Discriminator Loss:: 1.296585
# Epoch 37----Generator Loss:: 0.720843----Discriminator Loss:: 1.476712
# Epoch 37----Generator Loss:: 0.752082----Discriminator Loss:: 1.347796
# Epoch 37----Generator Loss:: 0.753037----Discriminator Loss:: 1.340771
# Epoch 37----Generator Loss:: 0.784537----Discriminator Loss:: 1.267457
# Epoch 37----Generator Loss:: 0.737772----Discriminator Loss:: 1.305883
# Epoch 38----Generator Loss:: 0.733293----Discriminator Loss:: 1.428266
# Epoch 38----Generator Loss:: 0.769115----Discriminator Loss:: 1.333664
# Epoch 38----Generator Loss:: 0.744349----Discriminator Loss:: 1.359803
# Epoch 38----Generator Loss:: 0.763226----Discriminator Loss:: 1.327036
# Epoch 38----Generator Loss:: 0.772484----Discriminator Loss:: 1.314717
# Epoch 39----Generator Loss:: 0.724048----Discriminator Loss:: 1.434152
# Epoch 39----Generator Loss:: 0.740894----Discriminator Loss:: 1.381882
# Epoch 39----Generator Loss:: 0.715767----Discriminator Loss:: 1.408748
# Epoch 39----Generator Loss:: 0.775214----Discriminator Loss:: 1.337418
# Epoch 39----Generator Loss:: 0.741516----Discriminator Loss:: 1.387366
# Epoch 40----Generator Loss:: 0.744142----Discriminator Loss:: 1.376781
# Epoch 40----Generator Loss:: 0.737729----Discriminator Loss:: 1.358958
# Epoch 40----Generator Loss:: 0.762465----Discriminator Loss:: 1.386751
# Epoch 40----Generator Loss:: 0.751023----Discriminator Loss:: 1.339110
# Epoch 40----Generator Loss:: 0.751160----Discriminator Loss:: 1.343595
# Epoch 41----Generator Loss:: 0.712053----Discriminator Loss:: 1.401944
# Epoch 41----Generator Loss:: 0.774599----Discriminator Loss:: 1.339075
# Epoch 41----Generator Loss:: 0.740992----Discriminator Loss:: 1.319690
# Epoch 41----Generator Loss:: 0.752507----Discriminator Loss:: 1.334898
# Epoch 41----Generator Loss:: 0.787874----Discriminator Loss:: 1.308892
# Epoch 42----Generator Loss:: 0.761759----Discriminator Loss:: 1.376093
# Epoch 42----Generator Loss:: 0.727763----Discriminator Loss:: 1.364024
# Epoch 42----Generator Loss:: 0.741575----Discriminator Loss:: 1.378374
# Epoch 42----Generator Loss:: 0.720360----Discriminator Loss:: 1.379363
# Epoch 42----Generator Loss:: 0.754132----Discriminator Loss:: 1.364842
# Epoch 43----Generator Loss:: 0.746484----Discriminator Loss:: 1.404776
# Epoch 43----Generator Loss:: 0.730843----Discriminator Loss:: 1.423610
# Epoch 43----Generator Loss:: 0.721583----Discriminator Loss:: 1.334796
# Epoch 43----Generator Loss:: 0.766791----Discriminator Loss:: 1.311504
# Epoch 43----Generator Loss:: 0.718871----Discriminator Loss:: 1.343907
# Epoch 44----Generator Loss:: 0.751072----Discriminator Loss:: 1.409478
# Epoch 44----Generator Loss:: 0.747671----Discriminator Loss:: 1.357119
# Epoch 44----Generator Loss:: 0.704322----Discriminator Loss:: 1.377596
# Epoch 44----Generator Loss:: 0.764383----Discriminator Loss:: 1.288919
# Epoch 44----Generator Loss:: 0.691617----Discriminator Loss:: 1.454192
# Epoch 45----Generator Loss:: 0.711400----Discriminator Loss:: 1.446832
# Epoch 45----Generator Loss:: 0.772308----Discriminator Loss:: 1.320373
# Epoch 45----Generator Loss:: 0.755916----Discriminator Loss:: 1.324798
# Epoch 45----Generator Loss:: 0.774662----Discriminator Loss:: 1.305656
# Epoch 45----Generator Loss:: 0.743845----Discriminator Loss:: 1.357396
# Epoch 46----Generator Loss:: 0.692256----Discriminator Loss:: 1.440394
# Epoch 46----Generator Loss:: 0.714069----Discriminator Loss:: 1.380139
# Epoch 46----Generator Loss:: 0.735646----Discriminator Loss:: 1.388542
# Epoch 46----Generator Loss:: 0.754892----Discriminator Loss:: 1.334263
# Epoch 46----Generator Loss:: 0.736911----Discriminator Loss:: 1.353701
# Epoch 47----Generator Loss:: 0.703956----Discriminator Loss:: 1.362085
# Epoch 47----Generator Loss:: 0.736911----Discriminator Loss:: 1.366816
# Epoch 47----Generator Loss:: 0.736479----Discriminator Loss:: 1.338974
# Epoch 47----Generator Loss:: 0.744708----Discriminator Loss:: 1.370355
# Epoch 47----Generator Loss:: 0.723488----Discriminator Loss:: 1.340761
# Epoch 48----Generator Loss:: 0.728185----Discriminator Loss:: 1.412138
# Epoch 48----Generator Loss:: 0.733639----Discriminator Loss:: 1.380303
# Epoch 48----Generator Loss:: 0.739398----Discriminator Loss:: 1.355495
# Epoch 48----Generator Loss:: 0.721503----Discriminator Loss:: 1.366638
# Epoch 48----Generator Loss:: 0.750688----Discriminator Loss:: 1.322720
# Epoch 49----Generator Loss:: 0.702710----Discriminator Loss:: 1.407411
# Epoch 49----Generator Loss:: 0.740443----Discriminator Loss:: 1.348428
# Epoch 49----Generator Loss:: 0.701672----Discriminator Loss:: 1.394246
# Epoch 49----Generator Loss:: 0.742771----Discriminator Loss:: 1.336132
# Epoch 49----Generator Loss:: 0.727092----Discriminator Loss:: 1.391537
# Epoch 50----Generator Loss:: 0.761888----Discriminator Loss:: 1.360725
# Epoch 50----Generator Loss:: 0.688538----Discriminator Loss:: 1.414730
# Epoch 50----Generator Loss:: 0.738255----Discriminator Loss:: 1.308609
# Epoch 50----Generator Loss:: 0.737349----Discriminator Loss:: 1.393581
# Epoch 50----Generator Loss:: 0.696040----Discriminator Loss:: 1.377490

# %%
## 。。。没有模式崩溃。。但好像也不是字了
test_num = 10
testlabel = np.ones(test_num)*3
testseed =tf.random.normal([test_num,noise_len])
FakeImgs = GModel((testseed,tf.convert_to_tensor(testlabel)),training=False)
showBatchImg(FakeImgs, testlabel)

# %%
DModel.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None)                    │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding (Embedding)         │ (None, 784)               │           7,840 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_layer_1 (InputLayer)    │ (None, 28, 28, 1)         │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape (Reshape)             │ (None, 28, 28, 1)         │               0 │ embedding[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 28, 28, 2)         │               0 │ input_layer_1[0][0],       │
# │                               │                           │                 │ reshape[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ sequential (Sequential)       │ (None, 1)                 │          95,681 │ concatenate[0][0]          │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 103,521 (404.38 KB)
#  Trainable params: 103,073 (402.63 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
GModel.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)    │ (None)                    │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_layer_3 (InputLayer)    │ (None, 50)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding_1 (Embedding)       │ (None, 50)                │             500 │ input_layer_4[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_1 (Concatenate)   │ (None, 100)               │               0 │ input_layer_3[0][0],       │
# │                               │                           │                 │ embedding_1[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ sequential_1 (Sequential)     │ (None, 28, 28, 1)         │         208,544 │ concatenate_1[0][0]        │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 209,044 (816.58 KB)
#  Trainable params: 208,596 (814.83 KB)
#  Non-trainable params: 448 (1.75 KB)
